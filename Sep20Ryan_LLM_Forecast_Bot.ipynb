# %% [markdown]
# <a href="https://colab.research.google.com/github/christianMet/metaculus-bot-forecaster/blob/main/Sep20Ryan_LLM_Forecast_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LLM Forecasting Bot
# *Created by Kirill and Tom, revised by Ryan*
#
# The code below is used for making LLM-powered forecasts in Metaculus' [AI benchmarking competition](https://www.metaculus.com/project/ai-benchmarking-pilot/).
#
# Specifically, it does the following:
#
# * Gets questions from the project page using the Metaculus API
# * Gets four separate forecasts from the LLM, three independently and the fourth assessing the reasoning of the first three and producing its own.
# * Predicts on the Metaculus questions and shares a comment describing the reasoning of the fourth LLM forecast.
#
# Features and options:
#
# * Allows you to choose whether it repredicts on questions it's already forecasted on or ignores them.
# * Allows for the use of [Perplexity search](https://www.perplexity.ai/) for additional research, using a prompt formed by an LLM.
#     * *Previously this allowed for the use of pre-computed Perpelxity results, but this is no longer supported by Metaculus.*
# * Can be used with an automated workflow via Github actions to monitor the project for new open questions and make forecasts when there are some
#     * See [this Github repo](https://github.com/ryooan/metaculus-bot-forecaster) for how to set this up

# %% [markdown]
# ### 🚨🚨🚨 Warning 🚨🚨🚨
#
# **You are responsible for monitoring the costs of your implementation, especially if using the automated Github workflow. Cost estimates computed by this notebook are rough estimates only, make sure to check and monitor how much you are spending and the funds in your relevant accounts.**

# %% [markdown]
# ## Getting Started
#
# ### Make a Metaculus Bot Account
# The first step will be to make a Metaculus bot account. Instructions for how to do this have likely already been provided to you, either via a page on Metaculus or at an event.
#
# ### Secrets and Tokens
#
# You need to set secrets 1) and 2) in order to make forecasts. Secrets 3) and 4) are necessary if you will be using Perplexity research.
#
# 1) METACULUS_TOKEN (you can find it or create it here - https://www.metaculus.com/admin/authtoken/tokenproxy/, or ask Metaculus to share it with you).
#
# 2) OPENAPI_API_KEY - (you can find it here https://platform.openai.com/settings/profile?tab=api-keys).
#
# 3) PERPLEXITY_API_KEY - You can generate an API key here: https://docs.perplexity.ai/docs/getting-started
#
# These secrets can be set in your Google colab account using the key on the left side.
#
# *See the [Github repo](https://github.com/ryooan/metaculus-bot-forecaster) for special instructions necessary for setting your secrets in Github if you intend to use the automated Github action.*
#
# *Note: previously this also used a QUESTIONS_API_KEY which got some precomputed Perplexity results stored by Metaculus, but this is no longer supported by Metaculus.*
#
# ### Setting Inputs
#
# Once your tokens are set correctly, you can proceed to the [Inputs section](https://colab.research.google.com/drive/1_P7_QNJiJyWBY2qCVu2-_8gVPD1X7mX3?authuser=2#scrollTo=6cbruBaVtaZh). That should be the only section most users will need. More advanced users can edit the [Setup](https://colab.research.google.com/drive/1_P7_QNJiJyWBY2qCVu2-_8gVPD1X7mX3?authuser=2#scrollTo=tNl_mbJaX60R) and [Code](https://colab.research.google.com/drive/1_P7_QNJiJyWBY2qCVu2-_8gVPD1X7mX3?authuser=2#scrollTo=k8vtze4SXtR3) sections if desired, but this is not recommended unless you have coding experience.

# %% [markdown]
# ## Setup
#
# It is recommended that you do not edit these cells unless you have coding experience.
#
#
#
# ---

# %%
from IPython.display import HTML, display

def set_css(*args, **kwargs):
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

#according to this link the above wraps the output text: https://stackoverflow.com/questions/58890109/line-wrapping-in-collaboratory-google-results

# %%
# !pip install openai
# !pip install tiktoken
# !pip install lxml_html_clean
import datetime
import json
import os
import requests
import tiktoken
import re

from openai import OpenAI

#use the below to detect if it's being run in google colab, if it's not this skips an error
def in_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

if in_colab():
    from google.colab import userdata
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Collecting openai
#   Downloading openai-1.47.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Downloading openai-1.47.0-py3-none-any.whl (375 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.6/375.6 kB 6.9 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.1 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 12.3 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: jiter, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jiter-0.5.0 openai-1.47.0
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.8.30)
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.7 MB/s eta 0:00:00
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.7.0
# Collecting lxml_html_clean
#   Downloading lxml_html_clean-0.2.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from lxml_html_clean) (4.9.4)
# Downloading lxml_html_clean-0.2.2-py3-none-any.whl (13 kB)
# Installing collected packages: lxml_html_clean
# Successfully installed lxml_html_clean-0.2.2

# %%
#the below is used to get secrets when using github actions to automate
#initialize
token = None
questions_api_key = None
perplexity_api_key = None

# Function to load secrets from the specified path
def load_secrets(secrets_path):
    try:
        with open(secrets_path, 'r') as secrets_file:
            secrets = json.loads(secrets_file.read())
            for k, v in secrets.items():
                os.environ[k] = v
    except Exception as e:
        print(f"Error loading secrets from {secrets_path}: {e}")

# Main code block
try:
    if 'secretsPath' in globals():
        print(f"secretsPath exists: {secretsPath}")
        load_secrets(secretsPath)

        token = os.environ['METACULUS_TOKEN']
       # questions_api_key = os.environ['QUESTIONS_API_KEY']
        perplexity_api_key = os.environ['PERPLEXITY_API_KEY']
    else:
        raise NameError("secretsPath not defined")
except NameError:
    print("Loading secrets from userdata (Google Colab)")
    token = userdata.get('METACULUS_TOKEN')
    os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
   # questions_api_key = userdata.get('QUESTIONS_API_KEY')
    perplexity_api_key = userdata.get('PERPLEXITY_API_KEY')
except KeyError as e:
    print(f"Missing required environment variable: {e}")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Loading secrets from userdata (Google Colab)

# %% [markdown]
# ## Inputs
#
# The cell below contains all of the main settings that you can change. See comments in the cell for an explanation of each. Modify them as you see fit and then run all of the cells below to forecast.
#
# *You can press Ctrl+F10 to run all of the cells after the selected one.*

# %%
PROJECT_ID = 3349  # 3129 is ID of AI Becnhmarking Pilot project. We kindly ask you not to forecast on any public tournaments or public questions in general
MAX_QUESTIONS_TO_FORECAST = 1_000  # You can set it to some small number for testing or to 1_000_000 to forecast on all available questions
REPREDICT = True # if this is false it won't predict on questions it has previously already predicted on. Set it to true to repredict on all open questions, even if it has made previous predictions.
SUBMIT_FORECASTS = True # If set to False - forecast, but don't submit results to Metaculus platform. If set to True - forecast, and submit results to Metaculus platform
USE_PERPLEXITY_RECENT = True # If set to true the perplexity search used is one that looks for the most recent news on the subject using a GPT prompt completion informed by the forecasting question.
QUESTION_IDS_TO_FORECAST = None # Set to None to disable custom filtering by ID. Set to a list of IDs to only forecast on selected questions, i.e. [24191, 24190, 24189]

# The forecaster weights are used to produce a weighted average of the forecasts. You can adjust these weights to favor a certain forecaster/prompt more heavily.
# Weights should sum to 1.
forecaster1_weight = 0.2
forecaster2_weight = 0.2
forecaster3_weight = 0.2
forecaster4_weight = 0.4

# Prompts
# The prompts used are below, these can be edited to hone your LLM forecasts.
# Here is a glossary of the variables that can be inserted and used in the prompts.
# [[title]]: This is the question text, what shows up at the top of the Metaculus question page
# [[resolution_criteria]]: This is the resolution criteria section of the question, excluding fine print
# [[fine_print]]: This is the fine print section of the question.
# [[background]]: This is the background section of the resolution criteria.
# [[today]]: The current date
# [[forecaster1]] through {forecaster3}: These are the LLM outputs of forecasters 1 through 3, currently being used to feed into the input of forecaster 4 for it to assess in its own forecast.
# [[summary_report]]: This is research from Perplexity. If USE_PERPLEXITY_RECENT is True, this will be the Perplexity info returned when the output of LLM_question_completion is passed to Perplexity.
                  # If USE_PERPLEXITY_RECENT is False and ENABLE_PERPLEXITY_RESEARCH is True, it will return pre-computed Perplexity research on the question stored by Metaculus.
                  # If both are false it will not return anything.

# The LLM_question_completion prompt is used to ask the LLM what question it should ask Perplexity, if using USE_PERPLEXITY_RECENT
LLM_question_completion = """
You're being asked the following forecasting question:

The question is:
[[title]]

And it has these specific resolution details:
[[resolution_criteria]]

Fine print:
[[fine_print]]

To get the latest news that will help you forecast on the question, you need to ask your web search tool one question that would be most valuable to help you forecast
on this question. The question should be posed so that the web search tool will provide you with the most recent information, including the latest information on the progress toward
the criteria in the forecasting question being met. Please complete the sentence below with the most valuable question to ask:

"What is the most recent news available and prior occurrences related to. . . "
"""

# Prompt 1 is used by forecaster 1, with PROMPT_TEMPLATE appended to the end
prompt1 = """
You are a professional forecaster interviewing for a job. The interviewer is also a professional forecaster, with a strong track record of accurate forecasts of the future.
They will ask you a question, and your task is to provide the most accurate forecast you can. To do this, you evaluate past data and trends carefully, make use of comparison classes
of similar events, take into account base rates about how past events unfolded, and outline the best reasons for and against any particular outcome.
You know that great forecasters don't just forecast according to the "vibe" of the question and the considerations.
Instead, they think about the question in a structured way, recording their reasoning as they go,
and they always consider multiple perspectives that usually give different conclusions, which they reason about together.
You can't know the future, and the interviewer knows that, so you do not need to hedge your uncertainty, you are simply trying to give
the most accurate numbers that will be evaluated when the events later unfold.

"""

# Prompt 2 is used by forecaster 2, with PROMPT_TEMPLATE appended to the end
prompt2 = """
You are a professional forecaster being tested on your skill. You are being asked a question for which you must provide the most accurate forecast you can.
Reason step by step about the best forecast, carefully considering the information you are presented with and the potential that some of the
background information and information provided by your research assistant may be out of date or conflicting.
You also know that a key forecasting practice is to consider the outside view, thinking carefully about reference classes and base rates and how often similar events
have happened in the past.

"""

# Prompt 3 is used by forecaster 3, with PROMPT_TEMPLATE appended to the end
prompt3 = """
You are a professional forecaster trying your best to produce an accurate forecast for the question below. You have a keen eye for detail, and know that
the resolution criteria and fine print of a question often contain important edge cases that should be considered. You also know that rookie forecasters
tend to be underconfident, and so your forecasts should be confident and extremize some of the way toward 1% or 99%. You're also aware that forecasting questions tend
to be biased, so when forecasting questions asks about things that would be a departure from the norm or from business as usual, those things tend not to happen.
You will use that knowledge to make the best forecast you can, and describe your reasoning step by step.

"""

# Forecaster 4 uses prompt 4 parts 1 and 2, with PROMPT_TEMPLATE inserted between part 1 and part 2
prompt4part1 = """
You are a professional forecaster trying your best to produce an accurate forecast for the question below.

"""

prompt4part2 = """
Now that you know what the question asks and some relevant background and research, your job is to make the best forecast you can. You know that examining the reasoning of other
forecasters is an excellent way to improve your own forecast. Below I have provided the reasoning from three other forecasters who predicted on the same question.
Examine their reasoning and use it to inform your own, using your expertise as a forecaster to assess which reasoning seems strongest and which seems flawed,
as well as which reasoning seems to incorporate the most accurate information about base rates and historic reference classes. Construct your own reasoning and forecast,
describing your reasoning step by step and incorporating the strongest arguments from the other forecasters in a way that improves your own reasoning. First produce a
one sentence summary of the reasoning of each forecaster (repeating the final probability each predicted), then describe your forecast.

Forecaster A:
[[forecaster1]]

Forecaster B:
[[forecaster2]]

Forecaster C:
[[forecaster3]]
"""

# PROMPT_TEMPLATE is used with the above prompts to share the details about the question with the LLM.
PROMPT_TEMPLATE = """

The question is:
[[title]]

Here are details about how the outcome of the question will be determined, make sure your forecast is consistent with these:
[[resolution_criteria]]

Here is the question's fine print that you need to be consistent with in your forecast:
[[fine_print]]

Here is some background of the question, though note that some of the details may be out of date:
[[background]]

Your research assistant provides the following information that is likely more up to date:
[[summary_report]]

Today is [[today]].

Describe your reasoning step by step and give your final answer as: "Probability: ZZ%", 0-100

Make sure the very last thing you output is the probability.
"""
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# ## Code
#
# It is recommended that you do not edit the below unless you have coding experience.
#
# Note that currently the LLM is set to gpt-4o, and this is specified in the code below. This can be changed by advanced users, though changing between OpenAI models is much simpler than changing to a model from a different AI organizations.
#
# ---

# %% [markdown]
# Getting questions (only binaries)
#
# Getting them 10 at a time, you can change offset to "scroll" through them

# %%
url = "https://www.metaculus.com/api2/questions/"

params = {
    "has_group": "false",
    "order_by": "-activity",
    "forecast_type": "binary",
    "project": PROJECT_ID,
    "status": "open", # can change this to 'closed' for testing where you're not submitting a forecast, otherwise leave as open
    "type": "forecast",
    "title-and-description-only": "true",
}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def yield_all_questions():
  limit = 10 # This is a page limit, not question limit
  n = 0
  new_questions_found = False

  while True:
    offset = n * limit
    response = requests.get(
        url,
        params={**params, "limit": limit, "offset": offset},
        headers={"Authorization": f"Token {token}"}
    )
    response.raise_for_status()
    questions = response.json().get("results")

    # if repredict is true it will skip to the else and predict on all the questions
    # if repredict is false it will see if "my_predictions" is empty or not for each question, and only predict on questions without a prediction
    if not REPREDICT:
        for question in questions:
            question_id = question['id']

            guess_response = requests.get(
                f"{url}{question_id}/",
                headers={"Authorization": f"Token {token}"}
            )
            guess_response.raise_for_status()

            if not guess_response.json().get("my_predictions"):
                new_questions_found = True
                yield question
    else:
        new_questions_found = True
        yield from questions

    if not response.json().get("next"):
      break
    n += 1

  if not new_questions_found:
        print("No new questions to predict on.")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def find_number_before_percent(s):
    # Use a regular expression to find all numbers followed by a '%'
    matches = re.findall(r'(\d+)%', s)
    if matches:
        # Return the last number found before a '%'
        return int(matches[-1])
    else:
        # Return None if no number found
        return None
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# this is used to replace the {} keys with [[]], since sometimes the LLM output uses {} when formatting code.

def replace_keys(text, key_dict, delimiter='[[', end_delimiter=']]'):
    pattern = re.compile(re.escape(delimiter) + '(.*?)' + re.escape(end_delimiter))
    def replace(match):
        key = match.group(1)
        return key_dict.get(key, match.group(0))  # Return the original if key not found
    return pattern.sub(replace, text)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def predict(question_id, prediction_percentage):
  url = f"https://www.metaculus.com/api2/questions/{question_id}/predict/"
  response = requests.post(
      url,
      json={
        "prediction": float(prediction_percentage) / 100
      },
      headers={"Authorization": f"Token {token}"},
  )
  response.raise_for_status()
  print(f"Successfully predicted {prediction_percentage} on question {question_id}")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def formulate_comment(prediction_json):
  comment_blocks = []
  if "reasoning_base_rate" in prediction_json:
    comment_blocks.append("## Base rate estimation")
    comment_blocks.append(prediction_json["reasoning_base_rate"])
  if "reasoning_reference_classes" in prediction_json:
    comment_blocks.append("## Reference classes")
    comment_blocks.append(prediction_json["reasoning_reference_classes"])
  if "reasoning_other" in prediction_json:
    comment_blocks.append("## Additional")
    comment_blocks.append(prediction_json["reasoning_other"])
  return "\n".join(comment_blocks) if comment_blocks else "No reasoning provided"
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def comment(question_id, comment_text):

  # for submit_type choose "S" to post regular comment and "N" for private. Tournament submissions should be private comments.
  url = f"https://www.metaculus.com/api2/comments/"
  response = requests.post(
    url,
    json={
      "comment_text":comment_text,"submit_type":"N","include_latest_prediction":True,"question":question_to_forecast['id']
    },
    headers={"Authorization": f"Token {token}"},
  )
  response.raise_for_status()
  print("Comment Success!")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def get_perplexity_research(question_id):
  url = "https://ml.metaculus.com/questions-api/perplexity-research-results/"
  headers = {
    "accept": "application/json",
    "X-API-Key": questions_api_key,
    "content-type": "application/json"
  }
  params = {
    "question_id": question_id
  }
  response = requests.get(url=url, params=params, headers=headers)
  if response.status_code == 404:
    print("No Perplexity research found")
    return "No results found, please use your own knowledge and judgement to forecast"
  content = response.text

  print("Generated research from perplexity:")
  print(content)
  return content
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def estimate_pricing(input, output, model):
  encoding = tiktoken.encoding_for_model(model)
  input_len = len(encoding.encode(input))
  output_len = len(encoding.encode(output))


  # hard coding for now, maybe make it smarter later
  # units of $ per token
  gpt4o_input_pricing = 5 / 1_000_000
  gpt4o_output_pricing = 15 / 1_000_000

  input_cost = input_len * gpt4o_input_pricing
  output_cost = output_len * gpt4o_output_pricing
  total_cost = input_cost + output_cost

  return input_cost, output_cost, total_cost
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def get_forecast(today, client, question_to_forecast, prompt, summary_report, model):

  title = question_to_forecast["title"]
  resolution_criteria = question_to_forecast["resolution_criteria"]
  background = question_to_forecast["description"]
  if question_to_forecast["fine_print"]:
    fine_print = question_to_forecast["fine_print"]
  else:
    fine_print = "none"

  print("")

  prompt_dict = {
      "title": title,
      "summary_report": summary_report,
      "today": today,
      "background": background,
      "fine_print": fine_print,
      "resolution_criteria": resolution_criteria,
  }

  prompt_content = replace_keys(prompt, prompt_dict)

  print("Here is the prompt used:")
  print(prompt_content)
  print("")

  chat_completion = client.chat.completions.create(
    model=model,
    messages=[
      {
        "role": "user",
        "content": prompt_content
      }
    ]
  )

  gpt_text = chat_completion.choices[0].message.content

  #estimate cost
  input_cost, output_cost, total_cost = estimate_pricing(prompt_content, gpt_text, model)

  # Regular expression to find the number following 'Probability: '
  probability_match = find_number_before_percent(gpt_text)

  # Extract the number if a match is found
  if probability_match:
      probability = int(probability_match) # int(match.group(1))
      print(f"The extracted probability is: {probability}%")
      #probability = min(max(probability, 3), 97) # To prevent extreme forecasts
  else:
      probability = None
      print("No probability found in the text! Skipping!")
  return probability, gpt_text, input_cost, output_cost, total_cost
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def call_perplexity(perplexity_prompt):
  model = "llama-3.1-sonar-large-128k-online"
  perplexity_token_pricing = 1/1_000_000
  perplexity_cost_fixed = 5/1_000

  url = "https://api.perplexity.ai/chat/completions"
  headers = {
    "accept": "application/json",
    "authorization": f"Bearer {perplexity_api_key}",
    "content-type": "application/json"
  }
  payload = {
    "model": model,
    "messages": [
      {
        "role": "system",
        "content": "Be precise and provide all the important details."
      },
      {
        "role": "user",
        "content": perplexity_prompt
      }
    ]
  }
  response = requests.post(url=url, json=payload, headers=headers)
  response.raise_for_status()
  content = response.json()["choices"][0]["message"]["content"]
  print("Generated research from perplexity:")
  print(content)

  # get token and cost estimate

  # currently using the GPT tokenizer with a 1.3 multiplier. Hacky and wrong, but rough estimate.
  # See here for 1.3 factor estimate source: https://github.com/continuedev/continue/issues/878

  multiplier = 1.3
  encoding = tiktoken.encoding_for_model('gpt-4o')
  input_text = perplexity_prompt
  output_text = content
  input_len = len(encoding.encode(input_text)) * multiplier
  output_len = len(encoding.encode(output_text)) * multiplier

  input_cost = input_len * perplexity_token_pricing
  output_cost = output_len * perplexity_token_pricing
  fixed_cost = perplexity_cost_fixed
  total_cost = input_cost + output_cost + perplexity_cost_fixed

  print(f"Total perplexity call cost: ${total_cost}")

  return content, total_cost
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def clean_gpt_turbo_markdown(text: str) -> str:
  match = re.search(r"```[\w]+\s+(.*?)\s+```", text, re.DOTALL)
  if match:
    cleaned_text = match.group(1).strip()
  else:
    cleaned_text = text
  return cleaned_text
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Forecast on all questions

# %%
today = datetime.datetime.now().strftime("%Y-%m-%d")
client = OpenAI()
model = "gpt-4o"
ENABLE_PERPLEXITY_RESEARCH = False  # Previously this could be set to True to get and use pre-computed Perplexity research results for the question, set to False otherwise.
# However, Metaculus no longer supports pre-computed Perplexity research, so it has been permanently set to False here to skip over that setp.

promptset = [prompt1 + PROMPT_TEMPLATE, prompt2 + PROMPT_TEMPLATE, prompt3 + PROMPT_TEMPLATE]

forecasted_count = 0

for question_to_forecast in yield_all_questions():
  if forecasted_count >= MAX_QUESTIONS_TO_FORECAST:
    break
  if QUESTION_IDS_TO_FORECAST is not None and question_to_forecast["id"] not in QUESTION_IDS_TO_FORECAST:
    continue

  print(question_to_forecast["id"], question_to_forecast["title"])

  #define perplexity research to use
  perplexity_total_cost = "N/A"

  if ENABLE_PERPLEXITY_RESEARCH:
    summary_report = get_perplexity_research(question_to_forecast["id"])
  else:
    summary_report = "No results found, please use your own knowledge and judgement to forecast"

  # set summary_report to the perplexity recent search if enabled
  if USE_PERPLEXITY_RECENT:
    #get prompt completion for use with perplexity
    probability, perplexity_recent_prompt, completion_input_cost, completion_output_cost, completion_total_cost = get_forecast(today, client, question_to_forecast, LLM_question_completion, summary_report, model)

    print(f"The completed question posed to perplexity reads: {perplexity_recent_prompt}")
    #get recent news from perplexity
    perplexity_content, perplexity_cost = call_perplexity(perplexity_recent_prompt)

    summary_report = perplexity_content
    perplexity_total_cost = completion_total_cost + perplexity_cost

  # need to iterate through prompts here
  all_forecasts = []
  overall_cost = 0

  for prompt in promptset:
    probability, gpt_text, input_cost, output_cost, total_cost = get_forecast(today, client, question_to_forecast, prompt, summary_report, model)
    all_forecasts.append((probability, gpt_text, input_cost, output_cost, total_cost))
    overall_cost += total_cost
    print(f"Output Reasoning:")
    print(gpt_text)
    print(f"Input cost: ${input_cost}")
    print(f"Output cost: ${output_cost}")
    print(f"Total cost: ${total_cost}")
    print(f"Perplexity search costs (including LLM prompt completion): ${completion_total_cost + perplexity_cost}")
    print("")
    print("~~~~ NEXT PROMPT ~~~~")
    print("")

  prompt4part2_dict = {
      "forecaster1": all_forecasts[0][1],
      "forecaster2": all_forecasts[1][1],
      "forecaster3": all_forecasts[2][1],
  }

  formatted_prompt4part2 = replace_keys(prompt4part2, prompt4part2_dict)

  print("+++++++++++FINAL PROMPT + ++++++++++++++++")

  prompt4 = prompt4part1 + PROMPT_TEMPLATE + formatted_prompt4part2

  probability, gpt_text, input_cost, output_cost, total_cost = get_forecast(today, client, question_to_forecast, prompt4, summary_report, model)

  forecaster1_weight = 0.2
  forecaster2_weight = 0.2
  forecaster3_weight = 0.2
  forecaster4_weight = 0.4

  weighted_forecast = forecaster1_weight*float(all_forecasts[0][0]) + forecaster2_weight*float(all_forecasts[1][0]) + forecaster3_weight*float(all_forecasts[2][0]) + forecaster4_weight*float(probability)
  weighted_forecast = int(weighted_forecast)
  overall_cost = overall_cost + total_cost

  #create summary strings for comments:
  header_string = f"""
  *This forecast is produced from four separate prompts. The first three produce independent forecasts and reasoning using different prompts, and the fourth reads the reasoning and forecasts fo the first three and produces its own forecast. Then a weighted forecast is produced from the four forecasts as described below. The reasoning shown is that of the fourth forecaster or "Summary Forecaster". See [the code](https://colab.research.google.com/drive/1_P7_QNJiJyWBY2qCVu2-_8gVPD1X7mX3?usp=sharing) for more info on the prompts used.*

  * *Model used: {model}*
  * *Weighted formula: ({forecaster1_weight})(Forecaster A) + ({forecaster2_weight})(Forecaster B) + ({forecaster3_weight})(Forecaster C) + ({forecaster4_weight})(Summary Forecaster)*
  * *Estimated cost of model calls based on tokens (excluding Perplexity info used): ${round(overall_cost,3)}*
  * *Estimated (rough) cost of Perplexity call (if using recent Perplexity search, and including LLM prompt completion): ${round(perplexity_total_cost,3)}*
  * ***Final weighted forecast: {weighted_forecast}%***

  ---

  """
  print(header_string)

  forecasted_count += 1
  if SUBMIT_FORECASTS and weighted_forecast is not None:
    predict(question_to_forecast["id"], float(weighted_forecast))
    comment(question_to_forecast["id"], header_string + "PERPLEXITY\n\n" + summary_report + "\n\n---\n\n" + "GPT\n\n" + gpt_text)

  print(f"Output Reasoning:")
  print(gpt_text)
  print("")
  print("FINAL WEIGHTED FORECAST:")
  print(f"{weighted_forecast}%")
  print("")
  print(f"Overall cost was: ${overall_cost}")
  print("")
  print("################ NEXT QUESTION #################")
  print("")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Streaming output truncated to the last 5000 lines.
# Here is the prompt used:
#
# You are a professional forecaster being tested on your skill. You are being asked a question for which you must provide the most accurate forecast you can.
# Reason step by step about the best forecast, carefully considering the information you are presented with and the potential that some of the
# background information and information provided by your research assistant may be out of date or conflicting.
# You also know that a key forecasting practice is to consider the outside view, thinking carefully about reference classes and base rates and how often similar events
# have happened in the past.
#
#
#
# The question is:
# Will the US national average retail price of regular gasoline be less than $3.00 on September 30, 2024, according to AAA?
#
# Here are details about how the outcome of the question will be determined, make sure your forecast is consistent with these:
# This question resolves as **Yes** if the value of the national average retail price of regular gas is <$3.000 on September 30, 2024, according to AAA, which can be accessed through the following link: [AAA National average gas prices](https://gasprices.aaa.com/) Specifically, on October 1, 2024, Metaculus will access the resolution link, and the number will resolve as the *Yesterday Avg.* for *Regular* gas.
#
# Here is the question's fine print that you need to be consistent with in your forecast:
# If the resolution source is inaccessible all day for Metaculus Admins on October 1, 2024, this question will be **annulled** due to a core assumption of this question being overturned. Please note this question makes certain other assumptions about the state of the world, such as AAA continuing its methodology, which it describes as, "Average gas prices are updated daily to reflect changes in price by gas grade and time frame listed." These key assumptions of the question being overturned, however, will cause this question to be annulled. Please refer to Metaculus's ambiguity and annulment policies [here](https://www.metaculus.com/help/faq/#ambiguous-annulled).
#
# Here is some background of the question, though note that some of the details may be out of date:
# According to the working paper Gasoline Prices and Presidential Approval Ratings of the United States (pdf [here](https://www.zbw.eu/econis-archiv/bitstream/11159/654462/1/1895045622_0.pdf)) in a multidecade study of Gallup polling, there is a correlation coefficient of -0.46 between a president's approval rating and real gas prices, with a p-value of 0.00. Indeed according to [S&P Global](https://www.spglobal.com/commodityinsights/en/market-insights/latest-news/oil/062624-us-elections-gasoline-price-fluctuations-could-play-role-in-2024-presidential-election), gas prices were strongly correlated with Joe Biden's disapproval ratings, at least until other factors such as the Israel-Hamas war became stronger influences:
#
# <img src="https://www.spglobal.com/commodityinsights/PlattsContent/_assets/_images/latest-news/3e5d524b-863e-488a-abaf-290df810d211.svg">
#
# The question of whether Kamala Harris, as Biden's Vice President, may benefit from a recent fall in gas prices, which are at nearly a [3-year low](https://www.newsweek.com/us-gas-prices-three-year-low-kamala-harris-1952733), is an open one. According to an analysis from [The Economic Times](https://economictimes.indiatimes.com/news/international/us/will-kamala-harris-get-a-bump-from-low-gas-prices-in-the-november-u-s-elections/articleshow/113298086.cms?from=mdr):
#
# >The decline is mostly the result of a confluence of economic factors rather than the direct intervention of the Biden administration. However, it might provide Vice President Harris with favourable obstacles regarding financial matters during the last few months of the campaign.
#
# >The COVID-19 pandemic and Russia's invasion of Ukraine in 2022 are two examples of recent global events that have caused higher gas prices. According to Patrick DeHaan, head of petroleum analysis at GasBuddy, the market is coming into a better sense of balance. So it certainly is good news for the incumbent party, potentially, that gas prices are falling, though he expects there will continue to be a lot of noise from politicians on both sides of the aisle on this issue.
#
# It is also important to note that historically there can be a lot of volatility in gas prices during election years:
#
# <img src="https://www.spglobal.com/commodityinsights/PlattsContent/_assets/_images/latest-news/f02e3ee4-fbc8-462f-b448-69d7fc39927b.svg">
#
# Please see chart of recent retail gas prices [here](https://ycharts.com/indicators/us_gas_price).
#
# Your research assistant provides the following information that is likely more up to date:
# Here is the most recent news and historical context regarding US national average retail gasoline prices, along with factors that affect them:
#
# ## Current Prices and Trends
# - As of September 2024, the national average retail gas price in the United States is approximately $3.32 per gallon, down from $3.36 the previous week and $3.941 one year ago, representing a -1.58% change from last week and a -16.09% change from one year ago.
# - The current price is slightly higher than the six-year national average of $3.05 per gallon since 2018.
#
# ## Recent Fluctuations
# - In 2024, the highest weekly national average gas price was $3.64 per gallon in early May, while the lowest was $3.05 per gallon in mid-January.
# - Gas prices have been decreasing recently; for example, the national average fell from $3.26 per gallon on September 12, 2024, to $3.23 per gallon on September 19, 2024.
#
# ## Historical Highs and Lows
# - The highest weekly national average gas price since 2018 was $4.99 per gallon in the week of June 16, 2022. During the same period, California saw prices as high as $6.43 per gallon.
# - The lowest weekly national average gas price since 2018 was $1.84 per gallon on April 16, 2020.
#
# ## Regional Variations
# - Gas prices vary significantly by state. In 2024, California had the highest average gas price at $5.45 per gallon, while Oklahoma had the lowest at $2.59 per gallon.
#
# ## Factors Affecting Gas Prices
# - **Global Oil Prices**: Gasoline prices are heavily influenced by crude oil prices. When crude oil prices rise, gasoline prices tend to follow.
# - **Demand and Supply**: Seasonal demand, geopolitical events, and supply chain disruptions can impact gas prices. For instance, higher demand during summer months can drive prices up.
# - **Regional Taxes and Regulations**: State and federal taxes, as well as local regulations, can also affect gas prices. States like California often have higher gas prices due to additional taxes and environmental regulations.
#
# ## Consumer Impact
# - Gas prices are a significant concern for American consumers, with 86% expressing concern about future price increases. This concern is slightly ahead of worries about household bills and groceries.
#
# ## Long-Term Projections
# - According to econometric models, US gasoline prices are expected to trend around $0.92 USD/Liter (approximately $3.49 per gallon) in 2025 and $0.93 USD/Liter (approximately $3.51 per gallon) in 2026.
#
# These factors and trends provide a comprehensive view of the current and historical context of US national average retail gasoline prices.
#
# Today is 2024-09-20.
#
# Describe your reasoning step by step and give your final answer as: "Probability: ZZ%", 0-100
#
# Make sure the very last thing you output is the probability.
#
#
# The extracted probability is: 35%
# Output Reasoning:
# To forecast whether the US national average retail price of regular gasoline will be less than $3.00 on September 30, 2024, we need to approach this methodically and consider several key aspects.
#
# ### Step-by-Step Reasoning:
#
# 1. **Current Price Analysis**:
#    - As of mid-September 2024, the average price is $3.32 per gallon.
#    - Recent trend shows a decrease, from $3.36 to $3.32 per gallon, a -1.58% change within a week.
#
# 2. **Recent Historical Context**:
#    - The price one year ago was notably higher at $3.941, but the price has been decreasing recently.
#    - For 2024, prices have fluctuated with a high of $3.64 in early May and low of $3.05 in mid-January.
#
# 3. **Long-Term Historical Data**:
#    - The six-year average (2018-2024) is $3.05, slightly above but near the range we're considering.
#    - Prior data illustrates volatility, with extreme lows ($1.84 in April 2020) and highs ($4.99 in June 2022).
#
# 4. **Factors Affecting Prices**:
#    - **Oil Prices**: Gas prices are closely related to crude oil prices. If oil prices rise, so will gas prices.
#    - **Demand & Supply**: Seasonal demand, geopolitical events, and supply issues also play critical roles.
#    - **Regional Taxes and Regulations**: Variations by state imply that regional policies could impact the national average.
#
# 5. **External Influences**:
#    - We must consider global events: the Russia-Ukraine war, potential new geopolitical tensions, and the ongoing economic recovery post-COVID-19.
#    - Historical and projected future trends suggest stabilizing rather than sharply dropping gasoline prices.
#
# 6. **Consumer Sentiment and Political Context**:
#    - High prices can affect consumer sentiment and political situations. This can indirectly influence government actions, potentially aiming to stabilize or reduce prices through policy measures, especially given the looming election.
#
# 7. **Reference Class Forecasting**:
#    - Looking at historical election years and recent price trends, gas prices typically experience volatility but do not consistently drop below significant benchmarks without strong economic reasons.
#
# ### Synthesis:
#
# - **Current Trend**: The price is steadily declining but remains above $3.00 as of mid-September 2024.
# - **Economic and Political Context**: Volatility around election years could cause spikes or drops, though recent actions to stabilize prices are possible.
# - **Historical Data**: Prices tend to fluctuate, but averaging out still shows figures above $3.00 in recent stable periods.
#
# ### Conclusion:
#
# Considering all factors – current pricing trends, historical data, influencing factors, and the broader context – it seems unlikely that the average price of regular gasoline will drop below $3.00 within ten days from now. However, the volatility factor does introduce some uncertainty. Therefore, I will assign a moderate probability taking all aspects into account.
#
# **Probability: 35%**
# Input cost: $0.008395000000000001
# Output cost: $0.00945
# Total cost: $0.017845
# Perplexity search costs (including LLM prompt completion): $0.0081304
#
# ~~~~ NEXT PROMPT ~~~~
#
#
# Here is the prompt used:
#
# You are a professional forecaster trying your best to produce an accurate forecast for the question below. You have a keen eye for detail, and know that
# the resolution criteria and fine print of a question often contain important edge cases that should be considered. You also know that rookie forecasters
# tend to be underconfident, and so your forecasts should be confident and extremize some of the way toward 1% or 99%. You're also aware that forecasting questions tend
# to be biased, so when forecasting questions asks about things that would be a departure from the norm or from business as usual, those things tend not to happen.
# You will use that knowledge to make the best forecast you can, and describe your reasoning step by step.
#
#
#
# The question is:
# Will the US national average retail price of regular gasoline be less than $3.00 on September 30, 2024, according to AAA?
#
# Here are details about how the outcome of the question will be determined, make sure your forecast is consistent with these:
# This question resolves as **Yes** if the value of the national average retail price of regular gas is <$3.000 on September 30, 2024, according to AAA, which can be accessed through the following link: [AAA National average gas prices](https://gasprices.aaa.com/) Specifically, on October 1, 2024, Metaculus will access the resolution link, and the number will resolve as the *Yesterday Avg.* for *Regular* gas.
#
# Here is the question's fine print that you need to be consistent with in your forecast:
# If the resolution source is inaccessible all day for Metaculus Admins on October 1, 2024, this question will be **annulled** due to a core assumption of this question being overturned. Please note this question makes certain other assumptions about the state of the world, such as AAA continuing its methodology, which it describes as, "Average gas prices are updated daily to reflect changes in price by gas grade and time frame listed." These key assumptions of the question being overturned, however, will cause this question to be annulled. Please refer to Metaculus's ambiguity and annulment policies [here](https://www.metaculus.com/help/faq/#ambiguous-annulled).
#
# Here is some background of the question, though note that some of the details may be out of date:
# According to the working paper Gasoline Prices and Presidential Approval Ratings of the United States (pdf [here](https://www.zbw.eu/econis-archiv/bitstream/11159/654462/1/1895045622_0.pdf)) in a multidecade study of Gallup polling, there is a correlation coefficient of -0.46 between a president's approval rating and real gas prices, with a p-value of 0.00. Indeed according to [S&P Global](https://www.spglobal.com/commodityinsights/en/market-insights/latest-news/oil/062624-us-elections-gasoline-price-fluctuations-could-play-role-in-2024-presidential-election), gas prices were strongly correlated with Joe Biden's disapproval ratings, at least until other factors such as the Israel-Hamas war became stronger influences:
#
# <img src="https://www.spglobal.com/commodityinsights/PlattsContent/_assets/_images/latest-news/3e5d524b-863e-488a-abaf-290df810d211.svg">
#
# The question of whether Kamala Harris, as Biden's Vice President, may benefit from a recent fall in gas prices, which are at nearly a [3-year low](https://www.newsweek.com/us-gas-prices-three-year-low-kamala-harris-1952733), is an open one. According to an analysis from [The Economic Times](https://economictimes.indiatimes.com/news/international/us/will-kamala-harris-get-a-bump-from-low-gas-prices-in-the-november-u-s-elections/articleshow/113298086.cms?from=mdr):
#
# >The decline is mostly the result of a confluence of economic factors rather than the direct intervention of the Biden administration. However, it might provide Vice President Harris with favourable obstacles regarding financial matters during the last few months of the campaign.
#
# >The COVID-19 pandemic and Russia's invasion of Ukraine in 2022 are two examples of recent global events that have caused higher gas prices. According to Patrick DeHaan, head of petroleum analysis at GasBuddy, the market is coming into a better sense of balance. So it certainly is good news for the incumbent party, potentially, that gas prices are falling, though he expects there will continue to be a lot of noise from politicians on both sides of the aisle on this issue.
#
# It is also important to note that historically there can be a lot of volatility in gas prices during election years:
#
# <img src="https://www.spglobal.com/commodityinsights/PlattsContent/_assets/_images/latest-news/f02e3ee4-fbc8-462f-b448-69d7fc39927b.svg">
#
# Please see chart of recent retail gas prices [here](https://ycharts.com/indicators/us_gas_price).
#
# Your research assistant provides the following information that is likely more up to date:
# Here is the most recent news and historical context regarding US national average retail gasoline prices, along with factors that affect them:
#
# ## Current Prices and Trends
# - As of September 2024, the national average retail gas price in the United States is approximately $3.32 per gallon, down from $3.36 the previous week and $3.941 one year ago, representing a -1.58% change from last week and a -16.09% change from one year ago.
# - The current price is slightly higher than the six-year national average of $3.05 per gallon since 2018.
#
# ## Recent Fluctuations
# - In 2024, the highest weekly national average gas price was $3.64 per gallon in early May, while the lowest was $3.05 per gallon in mid-January.
# - Gas prices have been decreasing recently; for example, the national average fell from $3.26 per gallon on September 12, 2024, to $3.23 per gallon on September 19, 2024.
#
# ## Historical Highs and Lows
# - The highest weekly national average gas price since 2018 was $4.99 per gallon in the week of June 16, 2022. During the same period, California saw prices as high as $6.43 per gallon.
# - The lowest weekly national average gas price since 2018 was $1.84 per gallon on April 16, 2020.
#
# ## Regional Variations
# - Gas prices vary significantly by state. In 2024, California had the highest average gas price at $5.45 per gallon, while Oklahoma had the lowest at $2.59 per gallon.
#
# ## Factors Affecting Gas Prices
# - **Global Oil Prices**: Gasoline prices are heavily influenced by crude oil prices. When crude oil prices rise, gasoline prices tend to follow.
# - **Demand and Supply**: Seasonal demand, geopolitical events, and supply chain disruptions can impact gas prices. For instance, higher demand during summer months can drive prices up.
# - **Regional Taxes and Regulations**: State and federal taxes, as well as local regulations, can also affect gas prices. States like California often have higher gas prices due to additional taxes and environmental regulations.
#
# ## Consumer Impact
# - Gas prices are a significant concern for American consumers, with 86% expressing concern about future price increases. This concern is slightly ahead of worries about household bills and groceries.
#
# ## Long-Term Projections
# - According to econometric models, US gasoline prices are expected to trend around $0.92 USD/Liter (approximately $3.49 per gallon) in 2025 and $0.93 USD/Liter (approximately $3.51 per gallon) in 2026.
#
# These factors and trends provide a comprehensive view of the current and historical context of US national average retail gasoline prices.
#
# Today is 2024-09-20.
#
# Describe your reasoning step by step and give your final answer as: "Probability: ZZ%", 0-100
#
# Make sure the very last thing you output is the probability.
#
#
# The extracted probability is: 15%
# Output Reasoning:
# To forecast whether the US national average retail price of regular gasoline will be less than $3.00 on September 30, 2024, we need to take a detailed look at various factors and consider the resolution criteria mentioned.
#
# ### Step-by-Step Reasoning:
#
# 1. **Current Price and Trend Analysis**:
#    - As of September 2024, the national average price is $3.32.
#    - The price has been falling recently, with a -1.58% change from last week.
#    - The trend is downward, but current prices are still significantly above $3.00.
#
# 2. **Historical Context**:
#    - The six-year national average (since 2018) is $3.05.
#    - The lowest price this year was $3.05 in mid-January.
#
# 3. **Volatility and Election Year Effects**:
#    - Gas prices tend to be volatile, especially in election years. Historical data shows significant fluctuations during such periods.
#    - However, given that the current trajectory is more influenced by economic factors rather than just political ones, sudden large drops may not be certain.
#
# 4. **Factors Influencing Future Prices**:
#    - **Global Oil Prices**: If crude oil prices were to fall significantly, it could pull gasoline prices down. As of now, there is no indication of such a sharp decline.
#    - **Demand and Supply**: Seasonal demand might affect prices, but we're looking at a fall timeline, when demand typically moderates.
#    - **Regional Variations**: High prices in states like California could skew the national average upward.
#
# 5. **Long-Term Projections**:
#    - Forecast models predict gasoline prices around $3.49 per gallon in 2025. This suggests prices are expected to be higher in the near future rather than drop significantly before the end of 2024.
#
# 6. **Resolution Criteria and Bias Considerations**:
#    - The forecast must be verified according to AAA on October 1, 2024.
#    - Statistical tendency indicates that large departures from the norm (current prices) are less probable.
#
# ### Final Forecast Calculation:
# - Given the current price is $3.32 and the general trend along with market predictions, a drop to below $3.00 is theoretically possible but unlikely.
# - No significant disruption or paradigm shift (e.g., major geopolitical event, sudden economic downturn) explicitly suggest a major price drop imminently.
# - Historical data supports that while fluctuations are common, such a drastic drop would be unusual within 10 days.
#
# ### Probability Calculation:
# - Considering the downward trend and slight recent reductions but balancing it against historical price behavior and market projections, the likelihood of a price below $3.00 on September 30, 2024, appears limited.
#
# Therefore, my final forecast is:
#
# **Probability: 15%**
# Input cost: $0.008605000000000002
# Output cost: $0.00861
# Total cost: $0.017215
# Perplexity search costs (including LLM prompt completion): $0.0081304
#
# ~~~~ NEXT PROMPT ~~~~
#
# +++++++++++FINAL PROMPT + ++++++++++++++++
#
# Here is the prompt used:
#
# You are a professional forecaster trying your best to produce an accurate forecast for the question below.
#
#
#
# The question is:
# Will the US national average retail price of regular gasoline be less than $3.00 on September 30, 2024, according to AAA?
#
# Here are details about how the outcome of the question will be determined, make sure your forecast is consistent with these:
# This question resolves as **Yes** if the value of the national average retail price of regular gas is <$3.000 on September 30, 2024, according to AAA, which can be accessed through the following link: [AAA National average gas prices](https://gasprices.aaa.com/) Specifically, on October 1, 2024, Metaculus will access the resolution link, and the number will resolve as the *Yesterday Avg.* for *Regular* gas.
#
# Here is the question's fine print that you need to be consistent with in your forecast:
# If the resolution source is inaccessible all day for Metaculus Admins on October 1, 2024, this question will be **annulled** due to a core assumption of this question being overturned. Please note this question makes certain other assumptions about the state of the world, such as AAA continuing its methodology, which it describes as, "Average gas prices are updated daily to reflect changes in price by gas grade and time frame listed." These key assumptions of the question being overturned, however, will cause this question to be annulled. Please refer to Metaculus's ambiguity and annulment policies [here](https://www.metaculus.com/help/faq/#ambiguous-annulled).
#
# Here is some background of the question, though note that some of the details may be out of date:
# According to the working paper Gasoline Prices and Presidential Approval Ratings of the United States (pdf [here](https://www.zbw.eu/econis-archiv/bitstream/11159/654462/1/1895045622_0.pdf)) in a multidecade study of Gallup polling, there is a correlation coefficient of -0.46 between a president's approval rating and real gas prices, with a p-value of 0.00. Indeed according to [S&P Global](https://www.spglobal.com/commodityinsights/en/market-insights/latest-news/oil/062624-us-elections-gasoline-price-fluctuations-could-play-role-in-2024-presidential-election), gas prices were strongly correlated with Joe Biden's disapproval ratings, at least until other factors such as the Israel-Hamas war became stronger influences:
#
# <img src="https://www.spglobal.com/commodityinsights/PlattsContent/_assets/_images/latest-news/3e5d524b-863e-488a-abaf-290df810d211.svg">
#
# The question of whether Kamala Harris, as Biden's Vice President, may benefit from a recent fall in gas prices, which are at nearly a [3-year low](https://www.newsweek.com/us-gas-prices-three-year-low-kamala-harris-1952733), is an open one. According to an analysis from [The Economic Times](https://economictimes.indiatimes.com/news/international/us/will-kamala-harris-get-a-bump-from-low-gas-prices-in-the-november-u-s-elections/articleshow/113298086.cms?from=mdr):
#
# >The decline is mostly the result of a confluence of economic factors rather than the direct intervention of the Biden administration. However, it might provide Vice President Harris with favourable obstacles regarding financial matters during the last few months of the campaign.
#
# >The COVID-19 pandemic and Russia's invasion of Ukraine in 2022 are two examples of recent global events that have caused higher gas prices. According to Patrick DeHaan, head of petroleum analysis at GasBuddy, the market is coming into a better sense of balance. So it certainly is good news for the incumbent party, potentially, that gas prices are falling, though he expects there will continue to be a lot of noise from politicians on both sides of the aisle on this issue.
#
# It is also important to note that historically there can be a lot of volatility in gas prices during election years:
#
# <img src="https://www.spglobal.com/commodityinsights/PlattsContent/_assets/_images/latest-news/f02e3ee4-fbc8-462f-b448-69d7fc39927b.svg">
#
# Please see chart of recent retail gas prices [here](https://ycharts.com/indicators/us_gas_price).
#
# Your research assistant provides the following information that is likely more up to date:
# Here is the most recent news and historical context regarding US national average retail gasoline prices, along with factors that affect them:
#
# ## Current Prices and Trends
# - As of September 2024, the national average retail gas price in the United States is approximately $3.32 per gallon, down from $3.36 the previous week and $3.941 one year ago, representing a -1.58% change from last week and a -16.09% change from one year ago.
# - The current price is slightly higher than the six-year national average of $3.05 per gallon since 2018.
#
# ## Recent Fluctuations
# - In 2024, the highest weekly national average gas price was $3.64 per gallon in early May, while the lowest was $3.05 per gallon in mid-January.
# - Gas prices have been decreasing recently; for example, the national average fell from $3.26 per gallon on September 12, 2024, to $3.23 per gallon on September 19, 2024.
#
# ## Historical Highs and Lows
# - The highest weekly national average gas price since 2018 was $4.99 per gallon in the week of June 16, 2022. During the same period, California saw prices as high as $6.43 per gallon.
# - The lowest weekly national average gas price since 2018 was $1.84 per gallon on April 16, 2020.
#
# ## Regional Variations
# - Gas prices vary significantly by state. In 2024, California had the highest average gas price at $5.45 per gallon, while Oklahoma had the lowest at $2.59 per gallon.
#
# ## Factors Affecting Gas Prices
# - **Global Oil Prices**: Gasoline prices are heavily influenced by crude oil prices. When crude oil prices rise, gasoline prices tend to follow.
# - **Demand and Supply**: Seasonal demand, geopolitical events, and supply chain disruptions can impact gas prices. For instance, higher demand during summer months can drive prices up.
# - **Regional Taxes and Regulations**: State and federal taxes, as well as local regulations, can also affect gas prices. States like California often have higher gas prices due to additional taxes and environmental regulations.
#
# ## Consumer Impact
# - Gas prices are a significant concern for American consumers, with 86% expressing concern about future price increases. This concern is slightly ahead of worries about household bills and groceries.
#
# ## Long-Term Projections
# - According to econometric models, US gasoline prices are expected to trend around $0.92 USD/Liter (approximately $3.49 per gallon) in 2025 and $0.93 USD/Liter (approximately $3.51 per gallon) in 2026.
#
# These factors and trends provide a comprehensive view of the current and historical context of US national average retail gasoline prices.
#
# Today is 2024-09-20.
#
# Describe your reasoning step by step and give your final answer as: "Probability: ZZ%", 0-100
#
# Make sure the very last thing you output is the probability.
#
# Now that you know what the question asks and some relevant background and research, your job is to make the best forecast you can. You know that examining the reasoning of other
# forecasters is an excellent way to improve your own forecast. Below I have provided the reasoning from three other forecasters who predicted on the same question.
# Examine their reasoning and use it to inform your own, using your expertise as a forecaster to assess which reasoning seems strongest and which seems flawed,
# as well as which reasoning seems to incorporate the most accurate information about base rates and historic reference classes. Construct your own reasoning and forecast,
# describing your reasoning step by step and incorporating the strongest arguments from the other forecasters in a way that improves your own reasoning. First produce a
# one sentence summary of the reasoning of each forecaster (repeating the final probability each predicted), then describe your forecast.
#
# Forecaster A:
# ## Step-by-Step Reasoning
#
# ### 1. Historical Context and Current Prices:
# Understanding both historical and current prices is crucial for setting a baseline. As of September 2024, the current national average retail gas price is approximately $3.32 per gallon. Comparing this to historical fluctuations:
# - The highest weekly price since 2018 was $4.99 in June 2022.
# - The lowest weekly price since 2018 was $1.84 in April 2020.
# - For most of 2024, the average price has fluctuated between $3.05 and $3.64.
#
# ### 2. Recent Trends:
# The recent trend shows a decrease in gas prices:
# - The national average fell from $3.26 per gallon on September 12, 2024, to $3.23 per gallon on September 19, 2024.
# - This is consistent with a general downward trend from the previous year, where prices have dropped by around 16.09%.
#
# ### 3. Factors Influencing Gas Prices:
# #### **Global Oil Prices:**
# Crude oil prices significantly impact gasoline prices. If global oil prices are to remain stable or decrease, it's plausible that gasoline prices could follow suit.
#
# #### **Seasonal Demand:**
# Demand typically increases during summer and decreases in the fall. Given we are moving into fall, this seasonal decrease in demand could favor a slight reduction in prices.
#
# #### **Geopolitical Events:**
# Geopolitical events can cause spikes or drops in oil prices. For now, no major geopolitical disruptions are forecasted, which might suggest relative stability.
#
# #### **Regional Variations & Taxes:**
# Regional factors and taxes can lead to variations, but these might not significantly influence the national average in short terms.
#
# ### 4. Comparison Classes:
# Reviewing similar scenarios:
# - Historical data from non-election years versus election years: Election years tend to show volatility, but this can swing prices either way.
# - Past decreases across a short time frame: Observing recent decreases over weeks.
#
# ### 5. Base Rates and Projections:
# Econometric models predict slight increases heading into 2025 ($3.49 per gallon) and 2026 ($3.51 per gallon).
#
# ### 6. Impact of External Factors:
# Consumer concerns and expectations, while high, don't directly determine prices but indicate demand. Concerns about price increases can sometimes lead to hoarding, spiking demand briefly. This factor is unpredictable but historically does not lead to long-term price changes.
#
# ### 7. Case Against Sub-$3.00 Price:
# - Current price at $3.32 per gallon is significantly higher than $3.00. A drop to under $3.00 within 10 days is substantial.
# - Econometric models project price levels above $3.00 for the near future.
# - Even with a downward trend, a significant reduction in 10 days is historically rare without significant events.
#
# ### 8. Case For Sub-$3.00 Price:
# - The downward trend from $3.32 might imply further drops.
# - If supply increases or demand drops more sharply than expected, prices can edge down to $3.00.
# - Minor decreases in global oil prices could push gas prices below $3.00.
#
# ### 9. Evaluating Likelihood:
# Given all factors:
# - Historical context supports stability around current levels or slight decreases.
# - Seasonal trends might help slightly.
# - Immediate drop to sub-$3.00 is unlikely without significant events, which aren’t currently visible.
#
# ### Conclusion
# The probability of the US national average retail price of regular gasoline being less than $3.00 on September 30, 2024, according to AAA, is low. Past and predicted trends, along with influencing factors, suggest that a drop below $3.00 in the next 10 days is improbable.
#
# ### Final Answer
# Probability: 10%
#
# Forecaster B:
# To forecast whether the US national average retail price of regular gasoline will be less than $3.00 on September 30, 2024, we need to approach this methodically and consider several key aspects.
#
# ### Step-by-Step Reasoning:
#
# 1. **Current Price Analysis**:
#    - As of mid-September 2024, the average price is $3.32 per gallon.
#    - Recent trend shows a decrease, from $3.36 to $3.32 per gallon, a -1.58% change within a week.
#
# 2. **Recent Historical Context**:
#    - The price one year ago was notably higher at $3.941, but the price has been decreasing recently.
#    - For 2024, prices have fluctuated with a high of $3.64 in early May and low of $3.05 in mid-January.
#
# 3. **Long-Term Historical Data**:
#    - The six-year average (2018-2024) is $3.05, slightly above but near the range we're considering.
#    - Prior data illustrates volatility, with extreme lows ($1.84 in April 2020) and highs ($4.99 in June 2022).
#
# 4. **Factors Affecting Prices**:
#    - **Oil Prices**: Gas prices are closely related to crude oil prices. If oil prices rise, so will gas prices.
#    - **Demand & Supply**: Seasonal demand, geopolitical events, and supply issues also play critical roles.
#    - **Regional Taxes and Regulations**: Variations by state imply that regional policies could impact the national average.
#
# 5. **External Influences**:
#    - We must consider global events: the Russia-Ukraine war, potential new geopolitical tensions, and the ongoing economic recovery post-COVID-19.
#    - Historical and projected future trends suggest stabilizing rather than sharply dropping gasoline prices.
#
# 6. **Consumer Sentiment and Political Context**:
#    - High prices can affect consumer sentiment and political situations. This can indirectly influence government actions, potentially aiming to stabilize or reduce prices through policy measures, especially given the looming election.
#
# 7. **Reference Class Forecasting**:
#    - Looking at historical election years and recent price trends, gas prices typically experience volatility but do not consistently drop below significant benchmarks without strong economic reasons.
#
# ### Synthesis:
#
# - **Current Trend**: The price is steadily declining but remains above $3.00 as of mid-September 2024.
# - **Economic and Political Context**: Volatility around election years could cause spikes or drops, though recent actions to stabilize prices are possible.
# - **Historical Data**: Prices tend to fluctuate, but averaging out still shows figures above $3.00 in recent stable periods.
#
# ### Conclusion:
#
# Considering all factors – current pricing trends, historical data, influencing factors, and the broader context – it seems unlikely that the average price of regular gasoline will drop below $3.00 within ten days from now. However, the volatility factor does introduce some uncertainty. Therefore, I will assign a moderate probability taking all aspects into account.
#
# **Probability: 35%**
#
# Forecaster C:
# To forecast whether the US national average retail price of regular gasoline will be less than $3.00 on September 30, 2024, we need to take a detailed look at various factors and consider the resolution criteria mentioned.
#
# ### Step-by-Step Reasoning:
#
# 1. **Current Price and Trend Analysis**:
#    - As of September 2024, the national average price is $3.32.
#    - The price has been falling recently, with a -1.58% change from last week.
#    - The trend is downward, but current prices are still significantly above $3.00.
#
# 2. **Historical Context**:
#    - The six-year national average (since 2018) is $3.05.
#    - The lowest price this year was $3.05 in mid-January.
#
# 3. **Volatility and Election Year Effects**:
#    - Gas prices tend to be volatile, especially in election years. Historical data shows significant fluctuations during such periods.
#    - However, given that the current trajectory is more influenced by economic factors rather than just political ones, sudden large drops may not be certain.
#
# 4. **Factors Influencing Future Prices**:
#    - **Global Oil Prices**: If crude oil prices were to fall significantly, it could pull gasoline prices down. As of now, there is no indication of such a sharp decline.
#    - **Demand and Supply**: Seasonal demand might affect prices, but we're looking at a fall timeline, when demand typically moderates.
#    - **Regional Variations**: High prices in states like California could skew the national average upward.
#
# 5. **Long-Term Projections**:
#    - Forecast models predict gasoline prices around $3.49 per gallon in 2025. This suggests prices are expected to be higher in the near future rather than drop significantly before the end of 2024.
#
# 6. **Resolution Criteria and Bias Considerations**:
#    - The forecast must be verified according to AAA on October 1, 2024.
#    - Statistical tendency indicates that large departures from the norm (current prices) are less probable.
#
# ### Final Forecast Calculation:
# - Given the current price is $3.32 and the general trend along with market predictions, a drop to below $3.00 is theoretically possible but unlikely.
# - No significant disruption or paradigm shift (e.g., major geopolitical event, sudden economic downturn) explicitly suggest a major price drop imminently.
# - Historical data supports that while fluctuations are common, such a drastic drop would be unusual within 10 days.
#
# ### Probability Calculation:
# - Considering the downward trend and slight recent reductions but balancing it against historical price behavior and market projections, the likelihood of a price below $3.00 on September 30, 2024, appears limited.
#
# Therefore, my final forecast is:
#
# **Probability: 15%**
#
#
# The extracted probability is: 15%
#
#   *This forecast is produced from four separate prompts. The first three produce independent forecasts and reasoning using different prompts, and the fourth reads the reasoning and forecasts fo the first three and produces its own forecast. Then a weighted forecast is produced from the four forecasts as described below. The reasoning shown is that of the fourth forecaster or "Summary Forecaster". See [the code](https://colab.research.google.com/drive/1_P7_QNJiJyWBY2qCVu2-_8gVPD1X7mX3?usp=sharing) for more info on the prompts used.*
#
#   * *Model used: gpt-4o*
#   * *Weighted formula: (0.2)(Forecaster A) + (0.2)(Forecaster B) + (0.2)(Forecaster C) + (0.4)(Summary Forecaster)*
#   * *Estimated cost of model calls based on tokens (excluding Perplexity info used): $0.084*
#   * *Estimated (rough) cost of Perplexity call (if using recent Perplexity search, and including LLM prompt completion): $0.008*
#   * ***Final weighted forecast: 18%***
#
#   ---
#
#
# Successfully predicted 18.0 on question 28306
# Comment Success!
# Output Reasoning:
# ### Summaries of Other Forecasters' Reasoning
#
# **Forecaster A:**
# Analyzed historical context, current prices, recent trends, and factors influencing gas prices to conclude a low probability of prices dropping below $3.00 within 10 days, stating it is highly unlikely without a significant event.
# **Probability: 10%**
#
# **Forecaster B:**
# Considered current and historical prices, factors influencing gas prices, and external influences, noting the volatility of election years but concluding that a significant drop below $3.00 within 10 days is unlikely yet somewhat plausible.
# **Probability: 35%**
#
# **Forecaster C:**
# Used current price trends, historical context, election year volatility, and factors like global oil prices and demand-supply dynamics to reason that although the possibility exists, it remains highly improbable for prices to fall below $3.00 by the end of September.
# **Probability: 15%**
#
# ### My Forecast
#
# #### Step-by-Step Reasoning
#
# 1. **Current Prices and Recent Trends:**
#    - The current national average price is $3.32 per gallon.
#    - Recent trends show a minor decrease, with a -1.58% drop over the last week.
#
# 2. **Historical Context and Data:**
#    - The 6-year average price since 2018 is $3.05, slightly above the threshold but not by much.
#    - Extreme highs and lows in recent years suggest potentials for volatility, but current trends are stable.
#
# 3. **Factors Affecting Gas Prices:**
#    - **Global Oil Prices:** Stable to slightly decreasing prices suggest a mild downward pressure.
#    - **Seasonal Demand:** Typically lower demand in the fall could exert downward pressure on prices.
#    - **Economic and Political Factors:** Volatile election years could lead to fluctuations, but no major events suggest a sudden price drop is imminent.
#
# 4. **Long-Term and Short-Term Projections:**
#    - Projections for 2025 and 2026 suggest hovering around $3.49-$3.51 per gallon.
#    - Short-term projections do not indicate significant disruptions that would cause a drastic price decrease.
#
# 5. **Comparative and Reference Class Forecasting:**
#    - Historical election year data shows volatility but not consistent price drops below $3.00 without significant catalysts.
#    - Recent history suggests minor weekly changes rather than sharp declines over short periods.
#
# 6. **Immediate Likelihood and Reasoning:**
#    - A drop from $3.32 to below $3.00 within 10 days represents a substantial decrease.
#    - Given historical context, such a drop is rare without major market events.
#
# #### Final Synthesis and Calculation:
# - Recent trends, historical data, influencing factors, and projections all point toward a low likelihood of prices dropping below $3.00 within the next 10 days.
# - While minor decreases are ongoing, the magnitude required to dip below $3.00 is significant and unsupported by forecasted events or market signals.
#
# Considering all these factors:
#
# **Probability: 15%**
#
# FINAL WEIGHTED FORECAST:
# 18%
#
# Overall cost was: $0.083775
#
# ################ NEXT QUESTION #################
#
# 28301 Will any of these large tech companies announce layoffs before October 1, 2024?
#
# Here is the prompt used:
#
# You're being asked the following forecasting question:
#
# The question is:
# Will any of these large tech companies announce layoffs before October 1, 2024?
#
# And it has these specific resolution details:
# This question resolves as **Yes** if, according to Tech Crunch's tracker *A comprehensive list of 2024 tech layoffs*, which currently can be accessed [here](https://techcrunch.com/2024/09/12/tech-layoffs-2024-list/), one of the following listed companies has layoffs in September 2024:
#
# - Amazon
# - Apple
# - Google or Alphabet
# - IBM
# - Meta or Facebook
# - Nvidia
# - Oracle
# - Salesforce
# - Tesla
#
# If no layoff event is listed under the September 2024 section for any of the above companies, this question resolves as **No**.
#
# Fine print:
# Tech Crunch's "comprehensive list of 2024 tech layoffs" will be the sole source used for resolution of this question, regardless of information from other sources.
#
# If on October 1, 2024, the time stamp on the resolution source is not September 30, 2024 or later, resolution will wait until up to October 7, 2024, for the entire month of September to be shown. If on October 7, 2024 the time stamp is not September 30, 2024 or later, this question resolves based on what is displayed at the resolution source at the time.
#
# In order to count, the Tech Crunch page must specifically list the company in question, regardless of subsidiaries or ownerships. So for example, if there is a layoff event at Waymo, it will not count for purposes of this question unless the subheading mentions Alphabet or Google, even though Waymo is owned by Alphabet.
#
# Tech Crunch's layoffs tracker dynamically updates its URL based on the last update. This question resolves based on the most recent version of the page that encompasses the month of September through September 30.
#
# To get the latest news that will help you forecast on the question, you need to ask your web search tool one question that would be most valuable to help you forecast
# on this question. The question should be posed so that the web search tool will provide you with the most recent information, including the latest information on the progress toward
# the criteria in the forecasting question being met. Please complete the sentence below with the most valuable question to ask:
#
# "What is the most recent news available and prior occurrences related to. . . "
#
#
# No probability found in the text! Skipping!
# The completed question posed to perplexity reads: "What is the most recent news available and prior occurrences related to layoffs at Amazon, Apple, Google/Alphabet, IBM, Meta/Facebook, Nvidia, Oracle, Salesforce, and Tesla?"
# Generated research from perplexity:
# Here is the most recent and relevant information on layoffs for the specified companies:
#
# ## Amazon
# - In April 2024, Amazon's cloud computing division, Amazon Web Services (AWS), laid off hundreds of employees across multiple teams, including sales, marketing, and global services. The layoffs were part of a strategy to shift focus to self-serve digital training and reduce duplication and inefficiency.
# - There have been ongoing discussions and speculations about potential further layoffs, particularly among managers, but no recent specific announcements have been made.
#
# ## Apple
# - On August 27, 2024, Apple announced layoffs affecting nearly 100 employees. This was part of a broader restructuring effort, though specific details are limited.
#
# ## Google/Alphabet
# - On May 31, 2024, Google laid off 100 employees across several Cloud “Go To Market” teams in the Asia-Pacific region. The affected teams included those responsible for consulting, partner engineering, and sustainability. Some new hires were also let go, though some were given time to find new roles within the company.
# - In October 2023, Google's news division initiated layoffs affecting 40-45 employees.
#
# ## IBM
# - There is no recent information available in the provided sources regarding layoffs at IBM.
#
# ## Meta/Facebook
# - In March 2023, Meta announced it was laying off an additional 13% of its staff, or more than 10,000 employees, as part of its "year of efficiency" initiative. This followed a previous round of layoffs in November 2022 that affected 11,000 employees.
#
# ## Nvidia
# - There is no recent information available in the provided sources regarding layoffs at Nvidia.
#
# ## Oracle
# - There is no recent information available in the provided sources regarding layoffs at Oracle.
#
# ## Salesforce
# - In 2024, Salesforce eliminated about 300 employees as part of a broader effort to cut costs and streamline its operations.
#
# ## Tesla
# - In April 2024, Tesla announced significant layoffs, including 6,020 employees in Texas and California, primarily due to slowing demand and falling margins. This round impacted 2,753 jobs at the Fremont gigafactory and Palo Alto offices. CEO Elon Musk indicated that Tesla could lay off at least 10% of its global workforce, potentially affecting around 14,000 employees.
# - Additionally, Tesla gutted its charging team in a new round of layoffs, and there are indications of further potential cuts.
#
# These updates reflect the most recent and relevant layoff information available for these companies as of September 2024.
# Total perplexity call cost: $0.0057176
#
# Here is the prompt used:
#
# ...
#
# Here is some background of the question, though note that some of the details may be out of date:
# Lex Fridman's podcast [is ranked](https://chartable.com/podcasts/artificial-intelligence-1434243584) #2 in the United States in the Technology category according to Apple and #61 overall. Recently he has been notable for his [interviews](https://lexfridman.com/podcast/) with Donald Trump, Elon Musk, Sam Altman, and Benjamin Netanyahu. His episode with Trump for example got 4.8 million views [on Youtube](https://www.youtube.com/watch?v=qCbfTN-caFI).
#
# On September 4, 2024, Fridman [tweeted](https://x.com/lexfridman/status/1831515121819987998):
#
# >I would love to do a podcast with [at]KamalaHarris
# >and other leading voices in the Democratic party including:<br>
# >- [at]GovTimWalz <br>
# >- [at]BarackObama<br>
# >- [at]HillaryClinton<br>
# >- [at]BernieSanders<br>
# >- [at]AOC
#
# >I think we can have amazing conversations!
#
# >I don't do gotcha-journalism, just a good-faith chat about life, philosophy, and ideas that hopefully helps reveal our common humanity.
#
# >It'll be fun, and great for everyone! ❤
#
# >DM's are open! 🙏
#
# Your research assistant provides the following information that is likely more up to date:
# As of the latest available information up to September 20, 2024, there is no specific mention in the provided sources about any of the individuals (Kamala Harris, Tim Walz, Barack Obama, Hillary Clinton, Bernie Sanders, Alexandria Ocasio-Cortez) appearing on podcasts or expressing a willingness to appear on podcasts.
#
# The sources primarily focus on their appearances and speeches at the 2024 Democratic National Convention, their political messages, and other related activities during the convention. There is no mention of podcast appearances or any intentions to participate in such events.
#
# For the most recent and detailed information on their potential podcast appearances, you would need to look at more current news articles or direct statements from these individuals that may have been released after the dates of the provided sources.
#
# Today is 2024-09-20.
#
# Describe your reasoning step by step and give your final answer as: "Probability: ZZ%", 0-100
#
# Make sure the very last thing you output is the probability.
#
# Now that you know what the question asks and some relevant background and research, your job is to make the best forecast you can. You know that examining the reasoning of other
# forecasters is an excellent way to improve your own forecast. Below I have provided the reasoning from three other forecasters who predicted on the same question.
# Examine their reasoning and use it to inform your own, using your expertise as a forecaster to assess which reasoning seems strongest and which seems flawed,
# as well as which reasoning seems to incorporate the most accurate information about base rates and historic reference classes. Construct your own reasoning and forecast,
# describing your reasoning step by step and incorporating the strongest arguments from the other forecasters in a way that improves your own reasoning. First produce a
# one sentence summary of the reasoning of each forecaster (repeating the final probability each predicted), then describe your forecast.
#
# Forecaster A:
# ### Step-by-Step Reasoning
#
# #### Step 1: Base Rate Analysis
# Let's start by considering the base rate for high-profile political figures such as prominent Democratic politicians appearing on popular podcasts like Lex Fridman’s. Although Lex Fridman has managed to interview other influential figures such as Donald Trump, Elon Musk, and Sam Altman, there’s no immediate evidence that he has been successful in securing interviews with top-tier Democratic politicians.
#
# #### Step 2: Recent Data
# The latest data from September 20, 2024, reveals no public statements or commitments from any of the specified Democrats about appearing on Lex Fridman's podcast. Given that the deadline for the forecast is October 1, 2024, there are merely 11 days left for any such appearance to occur. This significantly reduces the window of opportunity for any imminent podcast appearance.
#
# #### Step 3: Social Media Impact
# On September 4, 2024, Lex Fridman expressed his willingness on X (formerly Twitter) to interview these Democratic figures, but this social media outreach alone does not guarantee their appearances. The lack of public responses from these political figures to Fridman’s invitation as of September 20 reinforces this point.
#
# #### Step 4: Comparative Analysis
# Historically, political figures of similar stature have been selective about their media appearances, preferring platforms that align strategically with their current political objectives. Considering their busy schedules likely packed with campaign activities, especially given the proximity to the upcoming U.S. general elections, the likelihood diminishes further.
#
# #### Step 5: Factors For and Against
# - **Factors Favoring Appearance:**
#   1. Lex Fridman’s podcast is highly reputable and has featured other prominent and diverse figures.
#   2. The public nature of the invitation could exert some pressure on the political figures to engage in broader media outreach.
#
# - **Factors Against Appearance:**
#   1. The incredibly tight timeline of 11 days.
#   2. No indications or commitments from the Democrats in question about appearing.
#   3. The political climate and busy schedules of these politicians may discourage them from participating in this type of media engagement at this time.
#   4. Established patterns of high-profile political figures being cautious with media appearances close to elections.
#
# #### Step 6: Integrating Perspectives
# While Lex Fridman’s strong track record and the social media invitation are notable, the lack of confirmed commitments and the short timeframe make it highly improbable for any of these Democratic figures to appear on his podcast before the deadline.
#
# ### Final Probability
# Given the analysis above, it is prudent to assign a low probability to the event, acknowledging the possibility but considering it highly unlikely. Therefore, the final probability is:
#
# **Probability: 5%**
#
# Forecaster B:
# Let's carefully reason through each aspect of this prediction.
#
# ### 1. Establishing Reference Class and Base Rates
# **Reference Class**:
# The key question is: "How often do prominent Democratic politicians appear on non-traditional media platforms (like podcasts) hosted by prominent but non-mainstream figures?"
#
# **Base Rates**:
# We need to consider past appearances of similar figures on podcasts:
# - High-profile politicians like Barack Obama and Hillary Clinton have appeared on popular podcasts in the past (e.g., Obama on "WTF with Marc Maron" and Clinton on "Pod Save America").
# - More progressive figures like Bernie Sanders and Alexandria Ocasio-Cortez have also shown a willingness to engage in non-traditional media formats.
#
# **Specific Case: Lex Fridman Podcast**:
# Lex Fridman has shown success in securing interviews with high-profile figures like Donald Trump, Elon Musk, and Benjamin Netanyahu, indicating a strong likelihood of attracting major guests.
#
# ### 2. Assessing the Tweet by Lex Fridman
# - Fridman's tweet shows clear intent and desire to host these specific Democrats. This points to an increased likelihood that efforts are being made to actualize these appearances.
# - Given the tweet date (2024-09-04), there was almost a month to secure and record such interviews by now (2024-09-20).
#
# ### 3. Assessing Politicians' Likelihood to Appear
# - **Current Activities**: The politicians listed (Harris, Walz, Obama, Clinton, Sanders, Ocasio-Cortez) are indeed busy with political campaigns, conventions, and other obligations.
# - **Willingness for New Media**: Many of them have shown some openness to engaging with new media formats, as this can be critical for voter outreach.
# - **Podcast Timing and Scheduling**: Given the upcoming electoral cycle, making appearances on popular platforms could be strategically advantageous.
#
# ### 4. Potential Conflicts or Gaps in Information
# - **Research Assistant’s Information**: There's no mention up to September 20, 2024, of any podcast appearances. However, recordings done near or after the convention might be scheduled for release within the next 10 days before October 1, 2024.
# - **Outdated Information**: Political schedules can be rapidly changing, and a lack of specific information doesn't necessarily preclude last-minute arrangements or releases.
#
# ### 5. Balancing Inside and Outside Views
# - **Inside View**: Based on Fridman's history, the content and tone of his podcast, and the fact he has interviewed prominent figures recently, it's plausible he could secure such a high-profile guest.
# - **Outside View**: Historically, high-profile politicians do appear on popular podcasts, but these are less frequent and timely due to their political obligations and schedules.
#
# ### 6. Event-Specific Factors
# Given that Lex Fridman's podcast episodes are usually long-form, requiring significant scheduling and preparation, it's less likely for a high-profile politician to appear last-minute, but there's still some potential given the intersection of media and politics.
#
# ### Conclusion and Probability Assessment
# Combining all factors:
# - **General Willingness**: High potential given historical openness to new media.
# - **Specific Effort by Host**: Fridman is actively trying to secure these guests.
# - **Timing**: Short window until October 1, 2024, but efforts and recent tweets suggest a strong possibility of recent episodes being released soon.
#
# Given these combined perspectives and the uncertainties:
#
# **Probability: 25%**
#
# Probability: 25%
#
# Forecaster C:
# ### Step-by-Step Reasoning
#
# 1. **Understand the Question and Criteria**:
#     - The question asks if any of six prominent Democrats (Kamala Harris, Tim Walz, Barack Obama, Hillary Clinton, Bernie Sanders, Alexandria Ocasio-Cortez) will appear on the Lex Fridman podcast before October 1, 2024.
#     - Appearance criteria are based solely on their name appearing in red under an episode title more recent than #443 on the podcast page.
#     - Current date is September 20, 2024, implying only 10 days left for this to happen.
#
# 2. **Lex Fridman Podcast Context**:
#     - The podcast appears to be a high-profile platform, having hosted figures like Donald Trump and Elon Musk.
#     - Lex Fridman has openly invited these Democrats and mentioned his willingness to host them in a Tweet on September 4, 2024.
#
# 3. **Public Activities of the Democrats**:
#     - Recent sources indicate there's no mention of the listed Democrats expressing any intent or having scheduled podcast appearances.
#     - The focus of these individuals has been on mainstream political activities, particularly the Democratic National Convention.
#
# 4. **Factors to Consider**:
#     - **Scheduling and Preparation**: High-profile figures like these require significant coordination for appearances.
#     - **Time Constraint**: There are only 10 days left for an appearance to occur.
#     - **Podcast Release Timing**: Even if an interview were recorded, it would need to be edited and released before the deadline.
#     - **Historical Frequency**: There's no strong precedent indicating they frequently appear on lesser traditional media (like podcasts), especially with such tight schedules.
#
# 5. **Bias and Extreme Confidence**:
#     - Given tight schedules and the importance of traditional commitments, the likelihood of an unusual event (podcast appearance) happening on short notice is low.
#     - To adjust for rookie underconfidence, the probabilities will be extremized towards 1% or 99%.
#
# 6. **Calculation and Final Probability**:
#     - The combination of high-profile individuals, tight scheduling, lack of current engagements, and the short time window implies a very low likelihood.
#     - Therefore, the rational approach is to skew heavily towards the "No" outcome.
#
# ### Final Answer
# **Probability: 1%**
#
#
# The extracted probability is: 5%
#
#   *This forecast is produced from four separate prompts. The first three produce independent forecasts and reasoning using different prompts, and the fourth reads the reasoning and forecasts fo the first three and produces its own forecast. Then a weighted forecast is produced from the four forecasts as described below. The reasoning shown is that of the fourth forecaster or "Summary Forecaster". See [the code](https://colab.research.google.com/drive/1_P7_QNJiJyWBY2qCVu2-_8gVPD1X7mX3?usp=sharing) for more info on the prompts used.*
#
#   * *Model used: gpt-4o*
#   * *Weighted formula: (0.2)(Forecaster A) + (0.2)(Forecaster B) + (0.2)(Forecaster C) + (0.4)(Summary Forecaster)*
#   * *Estimated cost of model calls based on tokens (excluding Perplexity info used): $0.062*
#   * *Estimated (rough) cost of Perplexity call (if using recent Perplexity search, and including LLM prompt completion): $0.008*
#   * ***Final weighted forecast: 8%***
#
#   ---
#
#
# Successfully predicted 8.0 on question 28300
# Comment Success!
# Output Reasoning:
# ### Summary of Forecasters' Reasoning:
#
# **Forecaster A**:
# Analyzed the low base rate, the short 11-day timeframe, the social media impact, and comparative analysis of similar figures' media appearances. Considering the improbability, assigned a **5%** chance.
#
# **Forecaster B**:
# Looked at the general willingness of similar figures to appear on podcasts, Lex Fridman's active effort to invite these Democrats, and the strategic advantage of such appearances. Assigned a **25%** chance based on these factors and recent activity.
#
# **Forecaster C**:
# Focused on the tight schedule, historical frequency, and timing constraints, emphasizing the improbability of a last-minute podcast appearance. Adjusted for overall improbability and assigned a **1%** chance.
#
# ### My Forecast
#
# **Step 1: Base Rate Analysis**
# - High-profile Democratic politicians appearing on non-traditional media platforms like podcasts is relatively rare, especially in a narrow timeframe.
# - Notable appearances on other popular podcasts exist but are not frequent and often require significant scheduling.
#
# **Step 2: Timing and Schedule Constraints**
# - As of September 20, 2024, 11 days remain until the deadline. Given the busy schedules of these politicians, especially close to election activities, the chance of scheduling and recording such appearances is low.
# - The editing and releasing of the podcast episodes also need to be considered, reducing the practical window even further.
#
# **Step 3: Lex Fridman's Efforts and Influence**
# - Lex Fridman's significant outreach and reputation could positively impact the probability. His recent success with high-profile figures indicates strong persuasive ability.
# - The public invitation on social media might exert some influence, but as of now, there has been no public commitment from the invited figures.
#
# **Step 4: Comparative Analysis**
# - Political figures like Obama, Clinton, and Sanders have engaged with non-traditional media, but typically with more lead time and strategic alignment.
# - Current focus on mainstream political activities, particularly the Democratic National Convention, makes an immediate pivot to a podcast appearance unlikely.
#
# **Step 5: Balancing Factors**
# - **Factors Favoring Appearance**:
#   1. Lex Fridman’s established reputation and past guests.
#   2. Potential strategic outreach by politicians leveraging new media.
#
# - **Factors Against Appearance**:
#   1. The incredibly tight timeline.
#   2. No indications or public commitments by the politicians.
#   3. Political schedules dominated by campaign activities.
#
# **Step 6: Integrating and Adjusting**
# - While Fridman’s strong efforts and reputation could increase the chance slightly beyond the extremely low base rate, the short timeframe and lack of public response from the politicians minimize it substantially.
#
# ### Final Probability:
#
# **Probability: 5%**
#
# FINAL WEIGHTED FORECAST:
# 8%
#
# Overall cost was: $0.06223000000000001
#
# ################ NEXT QUESTION #################
